# %%
import csv

# %%
print("\n The most general hypothesis :['?','?','?','?','?','?']\n")
print("\n The most specific hypothesis :['0','0','0','0','0','0']\n")
# Out:
#  The most general hypothesis :['?','?','?','?','?','?']
#
#
#  The most specific hypothesis :['0','0','0','0','0','0']

# %%
a = []

# %%
with open('tennis.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        a.append(row)
        print(row)
    csvFile.close()

num_attributes = len(a[0]) - 1
# Out:
# ['outlook', 'temp', 'humidity', 'windy', 'play']
# ['sunny', 'hot', 'high', 'false', 'no']
# ['sunny', 'hot', 'high', 'true', 'no']
# ['overcast', 'hot', 'high', 'false', 'yes']
# ['rainy', 'mild', 'high', 'false', 'yes']
# ['rainy', 'cool', 'normal', 'false', 'yes']
# ['rainy', 'cool', 'normal', 'true', 'no']
# ['overcast', 'cool', 'normal', 'true', 'yes']
# ['sunny', 'mild', 'high', 'false', 'no']
# ['sunny', 'cool', 'normal', 'false', 'yes']
# ['rainy', 'mild', 'normal', 'false', 'yes']
# ['sunny', 'mild', 'normal', 'true', 'yes']
# ['overcast', 'mild', 'high', 'true', 'yes']
# ['overcast', 'hot', 'normal', 'false', 'yes']
# ['rainy', 'mild', 'high', 'true', 'no']

# %%
hypothesis = ['0'] * num_attributes
print('Initial Value of the hypothesis: ')
print(hypothesis)
# Out:
# Initial Value of the hypothesis:
# ['0', '0', '0', '0']

# %%
for j in range(0, num_attributes):
    hypothesis[j] = a[1][j]

# %%
print('\nFind S: Finding Maximally specific hypothesis\n')
for i in range(1, len(a)):
    if a[i][num_attributes] == 'yes':
        for j in range(num_attributes):
            if a[i][j] != hypothesis[j]:
                hypothesis[j] = '?'
            else:
                hypothesis[j] = a[i][j]
    print("For training example no :{0} the hypothesis is".format(
        i), hypothesis)
# Out:
# Find S: Finding Maximally specific hypothesis
#
# For training example no :1 the hypothesis is ['sunny', 'hot', 'high', 'false']
# For training example no :2 the hypothesis is ['sunny', 'hot', 'high', 'false']
# For training example no :3 the hypothesis is ['?', 'hot', 'high', 'false']
# For training example no :4 the hypothesis is ['?', '?', 'high', 'false']
# For training example no :5 the hypothesis is ['?', '?', '?', 'false']
# For training example no :6 the hypothesis is ['?', '?', '?', 'false']
# For training example no :7 the hypothesis is ['?', '?', '?', '?']
# For training example no :8 the hypothesis is ['?', '?', '?', '?']
# For training example no :9 the hypothesis is ['?', '?', '?', '?']
# For training example no :10 the hypothesis is ['?', '?', '?', '?']
# For training example no :11 the hypothesis is ['?', '?', '?', '?']
# For training example no :12 the hypothesis is ['?', '?', '?', '?']
# For training example no :13 the hypothesis is ['?', '?', '?', '?']
# For training example no :14 the hypothesis is ['?', '?', '?', '?']

# %%
print("\n The Maximally Specific Hypothesis for a given Training Examples:\n")
print(hypothesis)
# Out:
#  The Maximally Specific Hypothesis for a given Training Examples:
#
# ['?', '?', '?', '?']
